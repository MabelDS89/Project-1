# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import pprint

# %%
key = '70c09fd04588ce5a3c8846a236c15938'

# %%
states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]


c02_com = []

c02_ind = []

c02_res = []

count = 0

# %%
data = requests.get(commercialc02).json()
data1 = requests.get(industrialc02).json()
data2 = requests.get(residentialc02).json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8c60bb05e8e3> in <module>
# ----> 1 data = requests.get(commercialc02).json()
#       2 data1 = requests.get(industrialc02).json()
#       3 data2 = requests.get(residentialc02).json()
#
# NameError: name 'commercialc02' is not defined

# %%
for state_name in states:
    commercialc02 = f'http://api.eia.gov/series/?api_key=70c09fd04588ce5a3c8846a236c15938&series_id=EMISS.CO2-TOTV-CC-TO-{state_name}.A'
    industrialc02 = f'http://api.eia.gov/series/?api_key=70c09fd04588ce5a3c8846a236c15938&series_id=EMISS.CO2-TOTV-IC-TO-{state_name}.A'
    residentialc02 = f'http://api.eia.gov/series/?api_key=70c09fd04588ce5a3c8846a236c15938&series_id=EMISS.CO2-TOTV-RC-TO-{state_name}.A'
    data = requests.get(commercialc02).json()
    data1 = requests.get(industrialc02).json()
    data2 = requests.get(residentialc02).json()
    
    c02_com.append(data['series'][0]['data'])
    
    c02_ind.append(data1['series'][0]['data'])
    
    c02_res.append(data2['series'][0]['data'])
    
  
    count += 1
    if count > 53:
        break

# %%
x_2000 = []
x_2001 = []
x_2002 = []
x_2003 = []
x_2004 = []
x_2005 = []
x_2006 = []
x_2007 = []
x_2008 = []
x_2009 = []
x_2010 = []
x_2011 = []
x_2012 = []
x_2013 = []
x_2014 = []
x_2015 = []
y_2000 = []
y_2001 = []
y_2002 = []
y_2003 = []
y_2004 = []
y_2005 = []
y_2006 = []
y_2007 = []
y_2008 = []
y_2009 = []
y_2010 = []
y_2011 = []
y_2012 = []
y_2013 = []
y_2014 = []
y_2015 = []
z_2000 = []
z_2001 = []
z_2002 = []
z_2003 = []
z_2004 = []
z_2005 = []
z_2006 = []
z_2007 = []
z_2008 = []
z_2009 = []
z_2010 = []
z_2011 = []
z_2012 = []
z_2013 = []
z_2014 = []
z_2015 = []

# %%
com_c02 = c02_com[6:56]
ind_c02 = c02_ind[6:56]
res_c02 = c02_res[6:56]
#this loop requires manual changes to append each year
for lists in res_c02:
    z_2015.append(lists[2:18][0][:][1])

# %%
com_dict = {'States':states,
           '2000':x_2000,
           '2001':x_2001,
           '2002':x_2002,
           '2003':x_2003,
           '2004':x_2004,
           '2005':x_2005,
           '2006':x_2006,
           '2007':x_2007,
           '2008':x_2008,
           '2009':x_2009,
           '2010':x_2010,
           '2011':x_2011,
           '2012':x_2012,
           '2013':x_2013,
           '2014':x_2014,
           '2015':x_2015,
           }

# %%
main_commercial_df = pd.DataFrame(com_dict).set_index('States')

main_commercial_df
# Out:
#              2000       2001       2002       2003       2004       2005  \
# States
# AL       2.250348   2.163482   1.992439   2.101461   2.154941   1.844443
# AK       2.663767   2.458371   2.041855   1.921636   2.181861   2.093309
# AZ       2.191164   2.084873   2.164202   2.046614   2.020472   2.004572
# AR       2.106462   2.137350   2.132506   2.178835   2.020799   2.121101
# CA      14.366772  14.845360  14.231895  14.003348  14.118474  14.227760
# CO       3.796271   4.414418   4.346865   4.198701   4.068162   4.091438
# CT       4.511049   4.281812   4.098261   4.926948   3.906722   3.724782
# DE       0.631461   0.685537   0.745340   0.799474   0.790365   0.731721
# FL       4.795284   4.889205   5.003840   4.944626   5.843001   5.655670
# GA       4.140864   3.767390   3.362511   3.419756   3.785006   3.607969
# HI       0.276166   0.238709   0.310936   0.279577   0.328070   0.330632
# ID       1.073061   1.033828   0.983902   0.867845   0.977168   0.995737
# ...

# %%
ind_dict = {'States':states,
           '2000':y_2000,
           '2001':y_2001,
           '2002':y_2002,
           '2003':y_2003,
           '2004':y_2004,
           '2005':y_2005,
           '2006':y_2006,
           '2007':y_2007,
           '2008':y_2008,
           '2009':y_2009,
           '2010':y_2010,
           '2011':y_2011,
           '2012':y_2012,
           '2013':y_2013,
           '2014':y_2014,
           '2015':y_2015,
           }

# %%
main_industrial_df = pd.DataFrame(ind_dict).set_index('States')
main_industrial_df
# Out:
#               2000        2001        2002        2003        2004  \
# States
# AL       25.309891   21.915194   21.638640   22.865658   23.073684
# AK       21.072046   21.235824   21.650697   21.390271   20.530642
# AZ        4.252297    4.381861    3.774588    3.556457    3.931883
# AR       10.983514   10.985524   10.368701   10.402663   10.005143
# CA       65.096401   67.317006   67.995338   68.561117   71.613267
# CO        8.894194   12.427082   11.709776   11.401040   11.892432
# CT        2.582926    2.373072    2.222115    2.704866    2.436847
# DE        3.643422    3.642521    3.150996    2.850963    2.938396
# FL       13.838980   13.171936   11.506690   12.383540   11.026311
# GA       18.013652   17.501849   17.217536   17.943026   17.842204
# HI        1.327944    1.334162    1.385544    1.449727    1.396294
# ID        4.154096    3.926497    3.694007    3.366733    3.729507
# IL       39.611588   36.311906   35.669874   34.916094   34.856061
# ...

# %%
res_dict = {'States':states,
           '2000':z_2000,
           '2001':z_2001,
           '2002':z_2002,
           '2003':z_2003,
           '2004':z_2004,
           '2005':z_2005,
           '2006':z_2006,
           '2007':z_2007,
           '2008':z_2008,
           '2009':z_2009,
           '2010':z_2010,
           '2011':z_2011,
           '2012':z_2012,
           '2013':z_2013,
           '2014':z_2014,
           '2015':z_2015,
           }

# %%
main_residential_df = pd.DataFrame(res_dict).set_index('States')
main_residential_df
# Out:
#              2000       2001       2002       2003       2004       2005  \
# States
# AL       3.668102   3.541014   3.250241   3.089335   2.983225   2.721287
# AK       1.729165   1.796026   1.614116   1.652948   1.790486   1.760192
# AZ       2.130566   2.190491   2.166258   2.132916   2.241620   2.129516
# AR       2.915575   2.657313   2.622328   2.488219   2.252775   2.155681
# CA      27.556368  28.656476  28.675074  28.353830  29.435211  28.212989
# CO       6.891501   7.317984   7.598212   7.657142   7.281882   7.621822
# CT       8.608290   8.341462   8.079271   9.622951  10.101548   9.212632
# DE       1.210945   1.166879   1.175730   1.301599   1.215690   1.191424
# FL       1.514570   1.425698   1.379751   1.407868   1.543502   1.492089
# GA       8.718965   7.389082   7.651883   7.908541   7.771901   7.574943
# HI       0.076128   0.076675   0.077589   0.064904   0.064900   0.064831
# ID       1.516702   1.439563   1.424271   1.308573   1.560770   1.551396
# ...

# %%
main_commercial_df.to_csv('c02_df_data/commercial_c02.csv', index=True)
main_industrial_df.to_csv('c02_df_data/industrial_c02.csv', index=True)
main_residential_df.to_csv('c02_df_data/residential_c02.csv', index=True)
